# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\rajat\Downloads\data.csv')

# %%
np = df.to_numpy()
np
# Out:
# array([[  1.,  39.,   4., ...,  80.,  77.,   0.],
#        [  0.,  46.,   2., ...,  95.,  76.,   0.],
#        [  1.,  48.,   1., ...,  75.,  70.,   0.],
#        ...,
#        [  0.,  48.,   2., ...,  84.,  86.,   0.],
#        [  0.,  44.,   1., ...,  86.,  nan,   0.],
#        [  0.,  52.,   2., ...,  80., 107.,   0.]], shape=(4238, 16))

# %%
# Y = df["TenYearCHD"].values
# X = df[["male", "age", "cigsPerDay", "totChol", "sysBP", "glucose"]].values

# %%
Y = np[:, 15]
X = np[:, [0, 1, 4, 9, 10, 14]]

# %%
X = (X - X.mean(axis=0)) / (X.std(axis=0) + 1e-8)

# %%
df = df.fillna(df.mean(numeric_only=True))
print(df.isna().sum())
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
col_means = df.mean()
print("\nMean of each column:\n", col_means)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 col_means = np.mean(X, axis=0)
#       2 print("\nMean of each column:\n", col_means)
#
# TypeError: _mean() got multiple values for argument 'axis'

# %%
col_std = df.std()
print("\nStd dev of each column:\n", col_std)
# Out:
# Std dev of each column:
#  male                0.495022
# age                 8.572160
# education           1.007075
# currentSmoker       0.500024
# cigsPerDay         11.879230
# BPMeds              0.168520
# prevalentStroke     0.076587
# prevalentHyp        0.462763
# diabetes            0.158316
# totChol            44.326453
# sysBP              22.038097
# diaBP              11.910850
# BMI                 4.070953
# heartRate          12.025177
# glucose            22.836603
# TenYearCHD          0.359023
# dtype: float64

# %%
X = (X - X.mean(axis=0)) / (X.std(axis=0) + 1e-8)

# %%
class Linear_Regression():

    def __init__(self,learning_rate, no_of_iterations):

        self.learning_rate = learning_rate
        self.no_of_iterations = no_of_iterations

    def fit(self, X, Y):
        
        #no. of training examples and no. of features
        
        self.m, self.n = X.shape      #no. of rows and columns

        #weights and bias

        self.w = np.zeros(self.n)
        self.b = 0
        self.X = X
        self.Y = Y

        #Gradiant Descent

        for i in range(self.no_of_iterations):
            self.update_weights() 

            # print(w)
            # print(b)

    def update_weights(self):

        Y_prediction = self.predict(self.X)

        #calculate gradients

        dw = - (2 * (self.X.T).dot(self.Y - Y_prediction)) / self.m

        db = - 2 * np.sum(self.Y - Y_prediction) / self.m

        #update weights

        self.w = self.w - self.learning_rate*dw
        self.b = self.b - self.learning_rate*db

        print("Weights:", self.w)
        print("Bias:", self.b)
        print("Predictions:", Y_prediction[:5])

    def predict(self,X):

        return X.dot(self.w) + self.b

# %%
model = Linear_Regression(learning_rate=0.0001, no_of_iterations=10000)

model.fit(X, Y)

preds = model.predict(X)
print("Predictions:", preds)
print("Weights:", model.w)
print("Bias:", model.b)
# Out:
# Weights: [nan nan nan nan nan nan]
# Bias: nan
# Predictions: [nan nan nan nan nan]
# Weights: [nan nan nan nan nan nan]
# Bias: nan
# Predictions: [nan nan nan nan nan]
# Weights: [nan nan nan nan nan nan]
# Bias: nan
# Predictions: [nan nan nan nan nan]
# Weights: [nan nan nan nan nan nan]
# Bias: nan
# Predictions: [nan nan nan nan nan]
# Weights: [nan nan nan nan nan nan]
# Bias: nan
# Predictions: [nan nan nan nan nan]
# Weights: [nan nan nan nan nan nan]
# Bias: nan
# Predictions: [nan nan nan nan nan]
# Weights: [nan nan nan nan nan nan]
# Bias: nan
# Predictions: [nan nan nan nan nan]
# Weights: [nan nan nan nan nan nan]
# Bias: nan
# Predictions: [nan nan nan nan nan]
# Weights: [nan nan nan nan nan nan]
# Bias: nan
# Predictions: [nan nan nan nan nan]
# Weights: [nan nan nan nan nan nan]
# Bias: nan
# Predictions: [nan nan nan nan nan]
# Weights: [nan nan nan nan nan nan]
# Bias: nan
# Predictions: [nan nan nan nan nan]
# Weights: [nan nan nan nan nan nan]
# Bias: nan
# ...
